# %%
# %load_ext amazon_sagemaker_sql_magic

# %%
# %%sm_sql --connection-properties '{"connection_type": "ATHENA", "work_group": "primary"}'
#
#
# -- Query to list columns in table 'AwsDataCatalog.fare-prediction.raw'
# SELECT
#   *
# FROM
#   "AwsDataCatalog"."fare-prediction"."raw"
# Out:
#       trip_start_timestamp      trip_end_timestamp  trip_start_hour  \
# 0    05/17/2022 7:15:00 AM   05/17/2022 7:45:00 AM             7.25
# 1    05/17/2022 5:15:00 PM   05/17/2022 5:30:00 PM            17.25
# 2    05/17/2022 5:15:00 PM   05/17/2022 5:30:00 PM            17.25
# 3    05/17/2022 6:00:00 PM   05/17/2022 7:00:00 PM            18.00
# 4    05/17/2022 5:00:00 PM   05/17/2022 5:30:00 PM            17.00
# ..                     ...                     ...              ...
# 995  05/17/2022 2:15:00 PM   05/17/2022 2:30:00 PM            14.25
# 996  05/17/2022 4:15:00 PM   05/17/2022 4:30:00 PM            16.25
# 997  05/17/2022 9:45:00 AM  05/17/2022 10:15:00 AM             9.75
# 998  05/16/2022 8:15:00 PM   05/16/2022 8:15:00 PM            20.25
# 999  05/17/2022 7:00:00 PM   05/17/2022 7:30:00 PM            19.00
#
#      trip_seconds  trip_miles  trip_speed  pickup_census_tract  \
# 0            2341        2.57         4.0                  NaN
# ...
